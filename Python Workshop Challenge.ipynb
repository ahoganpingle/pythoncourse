# %%
import numpy as np
import matplotlib.pyplot as plt

norm = np.loadtxt("NOI-105872_010320_norm.dat")
norm15 = np.loadtxt("NOI-105872_010320_norm_bin15.dat")


fig = plt.figure(figsize=(10, 8))
plt.scatter(norm[:, 0] - 8852, norm[:, 2], marker='+', color='k', s = 40, label='60s') 

plt.scatter(norm15[:, 0] - 8852, norm60[:, 2], color='b', s = 80, label='x15')

plt.grid('on')
plt.title('NOI-105872 I band photometry SAAO 1m + SHOC 2020-01-03') 
plt.ylabel('flux')
plt.xlabel('JD - 2458852')


plt.ylim([0.91,1.03])
plt.xlim([0.31,0.57])

plt.legend()


plt.show()
